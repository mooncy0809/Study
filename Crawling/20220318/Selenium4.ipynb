# %%
import time   # sleep 지연
import os     # folder create 
import math   # ceil

from bs4 import BeautifulSoup      # Scraping(Crawling) package
from urllib.request import urlopen # 인터넷 접속후 페이지 소스 loading
from urllib.parse import quote     # 한글 처리 함수
from urllib.error import HTTPError # HTTP Exception
from requests import get           # GET 방식 호출

from selenium import webdriver  # 크롤링 이벤트 발생
driver = webdriver.Chrome('C:/kd/chromedriver.exe')

def load(url, second): # 페이지 열기
    try:
        driver.get(url)
        time.sleep(second) # Web page loading을 기다림, 초단위, 0.5: 0.5초
    except HTTPError as e:
        print(e)
        return None
    
def getbs(): # bs 객체 생성
    try:
        bs = BeautifulSoup(driver.page_source, 'html.parser') 
    except HTTPError as e:
        print(e)
        return None
    else:
        return bs
# Out:
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if sys.path[0] == '':

# %% [markdown]
# ### AWS 관측 장비를 이용한 대관령 날씨 정보 수집
# - https://www.weather.go.kr/weather/observation/aws_table_popup.jsp

# %%
load('https://www.weather.go.kr/weather/observation/aws_table_popup.jsp', 2)

# %%
bs = getbs()
print(bs)
# Out:
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta content="text/html;  charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>지역별상세관측자료(AWS)</title>
# <link href="/share/css/import.css?ver=20190625" rel="stylesheet" type="text/css"/>
# <script src="/share/js/common.js" type="text/javascript"></script>
# <meta content="designed_popup" name="decorator"/>
# <script src="/share/scriptaculous/lib/prototype.js" type="text/javascript"></script>
# <script src="/share/scriptaculous/scriptaculous.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/builder.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/effects.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/dragdrop.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/controls.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/slider.js" type="text/javascript"></script><script src="https://www.weather.go.kr/share/scriptaculous/sound.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		Event.observe(window, 'load', windowLoad, false);
# 		function windowLoad() {
# 			initFrames();
# 		}
# 	</script>
# <script src="/share/js/jquery-1.7.1.min.js" type="text/javascript"></script>
# <link href="/share/css/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <link href="/share/css/jquery-ui-timepicker-addon.css" rel="stylesheet" type="text/css"/>
# <script src="/share/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/share/js/datepicker-ko.js?ver=20190410" type="text/javascript"></script>
# <script src="/share/js/jquery-ui-timepicker-addon.js?ver=2019040102" type="text/javascript"></script>
# <!-- 	<script type="text/javascript" src="/share/js/jquery-ui-timepicker-ko.js"></script> -->
# </head>
# <body class="body_typoon_popup">
# <script type="text/javascript">
# 	//<!--
# 		function resizeFrameView(framename) {
# 			var the_height= document.getElementById(framename).contentWindow.document.body.scrollHeight;
# 			if(parseInt(the_height)<=0) return;
# 			//document.getElementById(framename).height= parseInt(the_height) + "px";
# 		}
#
# 		var io = null;
# 		function initFrames() {
# 			io = window.setInterval('checkFrames()',100);
# 		}
# 		function checkFrames() {
# 			if(window.menu) {
# 				//alert("menu");
# 				if(window.disp) {
# 					//alert("disp");
# 					if(window.disp.frames["all"]) {
# 						//alert("all");
# 						if(window.disp.frames["all"].frames["sub"]) {
# 							//alert("sub");
# 							if(io) window.clearInterval(io);
# 							window.menu.stn_select(4108);
# 						}
# 					}
# 				}
# 			}
# 		}
# 	//-->
# 	</script>
# <noscript>
# </noscript>
# <h1>지역별상세관측자료(AWS)</h1>
# <div id="wrap_content_aws">
# <div id="title_aws">
# <h2 class="fl"><img alt="지상관측자료" src="../../images/weather/observation/h4_1_1.gif"/></h2>
# <h3 class="fl"><img alt="지역별상세관측자료(AWS)" src="../../images/weather/observation/h5_1_3.gif"/></h3>
# <ul class="button_aws">
# <li class="print"><a href="/HELP/html/help_aws001.jsp" onclick="window.open(this.href, 'enlargeView', 'width=1000,height=700,scrollbars=no'); return false;" onkeypress="this.onclick();" title="새창 (팝업에서 열림)"><img alt="도움말" src="../../images/common/btn_help.gif"/></a></li>
# <!--<li class="print"><a href="/weather/observation/aws_table_popup.jsp?printable=true&" onclick="window.open('aws_print.jsp?printable=true&url=' + escape(window.disp.frames['body'].location.href), 'enlargeView', 'width=1000,scrollbars=yes'); return false;" onkeypress="this.onclick();" title="새창 (팝업에서 열림)"><img src="../../images/common/btn_print.gif" alt="인쇄하기" /></a></li>-->
# </ul>
# </div>
# <div id="content">
# <!-- content :Start -->
# <ul id="tab_nav">
# <li><a class="active" href="aws_table_popup.jsp"><img alt="문숫자" src="https://www.weather.go.kr/images/weather/observation/tab_aws1_on.gif"/></a></li>
# <li><a href="aws_distribution_popup.jsp"><img alt="분포도" src="../../images/weather/observation/tab_aws2.gif"/></a></li>
# <li><a href="aws_graph_popup.jsp"><img alt="그래프" src="../../images/weather/observation/tab_aws3.gif"/></a></li>
# </ul>
# <script type="text/javascript">initImgEffect("tab_nav",'0');</script>
# <div style="z-index:0;  position:absolute; width:100%;">
# <iframe frameborder="0" height="50px" id="menu" marginheight="0" marginwidth="0" name="menu" scrolling="no" src="aws_table_menu.jsp" title="지역별상세관측자료 문숫자 메뉴" width="100%"></iframe>
# </div>
# <!-- 2019-04-09 달력 선택란 추가-->
# <div style="width:200px; height:50px;  z-index:3; position:relative; margin:0px 0 0px 230px;">
# <form action="aws_table_popup.jsp" id="frm" method="get" name="frm" onsubmit="return false;" target="body">
# <table style="float:left; margin-top:10px;">
# <tbody><tr>
# <td><input class="hasDatepicker" id="datecal2" name="tm1" size="20" type="text"/><img alt="날짜 선택" class="ui-datepicker-trigger" src="/images/icon_calendar.gif" title="날짜 선택"/></td>
# <td> <input alt="선택" class="btn" onclick="javascript:window.menu.tm_input(true,event);" onkeypress="this.onclick" src="../../images/weather/forecast/btn_select.gif" type="image"/></td>
# </tr>
# </tbody></table>
# </form>
# </div>
# <div style="z-index:2;  position:relative;">
# <iframe frameborder="0" height="730px" id="disp" marginheight="0" marginwidth="0" name="disp" scrolling="no" src="aws_table_panel.jsp" title="지역별상세관측자료 문숫자 " width="100%"></iframe></div>
# <script language="javascript" type="text/javascript">
#                 //<![CDATA[
#                     Event.observe(document.getElementById('disp'), 'load',resizeFrameViewDisp, false);
#                     function resizeFrameViewDisp() {
#                         var the_height= document.getElementById("disp").contentWindow.document.body.scrollHeight;
#                         if(parseInt(the_height)<=0) return;
#                         //document.getElementById(framename).height= parseInt(the_height) + "px";
#                     }
#                 //]]>
#                 </script>
# <div class="btn_close"><a href="#" onclick="parent.close(); return false;" onkeypress="this.onclick();"><img alt="창닫기" src="../../images/member/btn_popup_close.gif"/></a></div>
# <!-- content :End -->
# </div>
# </div>
# <script type="text/javascript">
# 	var nowDate = new Date();
# 	var minDate = new Date();
# 	minDate.setYear(2017);
# 	minDate.setMonth(0);
# 	minDate.setDate(1);
# 	// var mod = "";
# 	var mod = document.forms["frm"].tm1.value;
# 	//if(mod == "") { mod = nowDate; }
# 	$(function(){
# 		$("#datecal").datepicker({
# 			showOn: "both",
# 			buttonImage: "/images/icon_calendar.gif",
# 			buttonImageOnly: true,
# 			buttonText: "날짜 선택",
# 			changeMonth: true,
# 			changeYear: true,
# 			showButtonPanel: true,
# 			minDate: minDate,
# 			maxDate: nowDate
# 		}).datepicker("setDate", mod);
# 	});
# 	$(function(){
# 		$("#datecal2").datetimepicker({
# 			showOn: "both",
# 			buttonImage: "/images/icon_calendar.gif",
# 			buttonImageOnly: true,
# 			buttonText: "날짜 선택",
# 			changeMonth: true,
# 			changeYear: true,
# 			showButtonPanel: true,
# 			minDate: minDate,
# 			maxDate: nowDate,
# 			timdFormat:"HH:mm",
# 			controlType: 'select',
# 			oneLine:true
# 		}).datetimepicker("setDate", mod);
# 	});
# </script>
# <!-- 긴급작업공지 공지가 필요한 경우 // 주석 지움 -->
# <script src="/common/cookie.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	// 2018-11-27 aws 자료미표출 팝업 공지
# //	var nowDate = new Date();
# //	var c_Id = "";
# //	c_Id += nowDate.getFullYear();
# //	c_Id += "_" + nowDate.getMonth();
# //	c_Id += "_" + nowDate.getDate();
# //	c_Id += "_" + nowDate.getDay();
# //	if (getCookie("popup_notice_aws"+c_Id) == "cl_td_pop_y") {
# //	} else {
# //		window.open("http://dev2www.kma.go.kr/popup/popup_notice_aws.html", "popup_notice_aws","width=500,height=285,left=100,top=60,toolbar=no,location=no,status=no,menubar=no,scrollbars=no,resizable=no");
# //	}
# </script>
# <div class="ui-datepicker ui-widget ui-widget-content ui-helper-clearfix ui-corner-all" id="ui-datepicker-div"><div class="ui-datepicker-header ui-widget-header ui-helper-clearfix ui-corner-all"><a class="ui-datepicker-prev ui-corner-all" data-event="click" data-handler="prev" title="이전달"><span class="ui-icon ui-icon-circle-triangle-w">이전달</span></a><a class="ui-datepicker-next ui-corner-all ui-state-disabled" title="다음달"><span class="ui-icon ui-icon-circle-triangle-e">다음달</span></a><div class="ui-datepicker-title"><select class="ui-datepicker-year" data-event="change" data-handler="selectYear"><option value="2017">2017</option><option value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option><option value="2021">2021</option><option selected="selected" value="2022">2022</option></select>년<select class="ui-datepicker-month" data-event="change" data-handler="selectMonth"><option value="0">1월</option><option value="1">2월</option><option selected="selected" value="2">3월</option></select></div></div><table class="ui-datepicker-calendar"><thead><tr><th class="ui-datepicker-week-end" scope="col"><span title="일요일">일</span></th><th scope="col"><span title="월요일">월</span></th><th scope="col"><span title="화요일">화</span></th><th scope="col"><span title="수요일">수</span></th><th scope="col"><span title="목요일">목</span></th><th scope="col"><span title="금요일">금</span></th><th class="ui-datepicker-week-end" scope="col"><span title="토요일">토</span></th></tr></thead><tbody><tr><td class="ui-datepicker-week-end ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled"> </td><td class="ui-datepicker-other-month ui-datepicker-unselectable ui-state-disabled"> </td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">1</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">2</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">3</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">4</a></td><td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">5</a></td></tr><tr><td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">6</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">7</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">8</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">9</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">10</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">11</a></td><td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">12</a></td></tr><tr><td class="ui-datepicker-week-end" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">13</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">14</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">15</a></td><td class="" data-event="click" data-handler="selectDay" data-month="2" data-year="2022"><a class="ui-state-default" href="#">16</a></td ...

# %%
# 대관령 click event 발생
#s100 > table > tbody > tr > td
#//*[@id="s100"]/table/tbody/tr/td
driver.find_element_by_xpath('//*[@id="s100"]/table/tbody/tr/td')
print(tag.text)
# Out:
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_6248\2565175074.py in <module>
#       2 #s100 > table > tbody > tr > td
#       3 #//*[@id="s100"]/table/tbody/tr/td
# ----> 4 driver.find_element_by_xpath('//*[@id="s100"]/table/tbody/tr/td')
#       5 print(tag.text)
#
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
# -> 1250             'value': value})['value']
#    1251
#    1252     def find_elements(self, by=By.ID, value=None) -> List[WebElement]:
#
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\envs\ai\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="s100"]/table/tbody/tr/td"}
#   (Session info: chrome=99.0.4844.74)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B79943+2595139]
# 	Ordinal0 [0x00B0C9F1+2148849]
# 	Ordinal0 [0x00A04528+1066280]
# 	Ordinal0 [0x00A30FD4+1249236]
# 	Ordinal0 [0x00A311CB+1249739]
# 	Ordinal0 [0x00A5D812+1431570]
# 	Ordinal0 [0x00A4BA34+1358388]
# 	Ordinal0 [0x00A5BAF2+1424114]
# 	Ordinal0 [0x00A4B806+1357830]
# 	Ordinal0 [0x00A26086+1204358]
# 	Ordinal0 [0x00A26F96+1208214]
# 	GetHandleVerifier [0x00D1B232+1658114]
# 	GetHandleVerifier [0x00DD312C+2411516]
# 	GetHandleVerifier [0x00C0F261+560433]
# 	GetHandleVerifier [0x00C0E366+556598]
# 	Ordinal0 [0x00B1286B+2173035]
# 	Ordinal0 [0x00B175F8+2192888]
# 	Ordinal0 [0x00B176E5+2193125]
# 	Ordinal0 [0x00B211FC+2232828]
# 	BaseThreadInitThunk [0x7634FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776F7A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776F7A4E+238]
