# %% [markdown]
# ## 데이터 전처리, 모델 제작용 변수 선택, 생성

# %% [markdown]
# - PassengerId int64  승객 id
# - Survived int64      0:사망, 1: 생존
# - Pclass int64         티켓등급: 1등석, 2등석, 3등석
# - Name object       성명
# - Sex object          성별
# - Age float64         나이
# - SibSp int64         승선중인 형제나 배우자의 수
# - Parch int64         승선중인 부모나 자녀의 수
# - Ticket object       티케 번호
# - Fare float64         티켓 요금
# - Cabin object        반 번호
# - Embarked object  승선한 항구의 이름 C: Cherbourg, Q:Queenstown, S: Southampton

# %%
import warnings
warnings.filterwarnings("ignore")

import random
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

#2개의 Dataframe을 연결 병합, srot=False: 병합후 index에 따라 정렬
df = pd.concat([train_df, test_df],sort=False).reset_index(drop=True)
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
#결측치 확인
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# ### 티켓등급별 중위수를 구하여 Fare가 결측치인 승객의 Fare에 값을 할당

# %%
# 파생 변수 : 기존의 변수에 사칙연산을 가하여 정확도를 높이는 변수를 추가하는 기법
# 티켓 등급별 평균 요금 파생 변수의 추가
fare_mean = df[['Pclass','Fare']].groupby('Pclass').mean() #평균은 이상치의 영향을 받음. median권장
fare_mean
# Out:
#              Fare
# Pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %%
# 파생 변수 : 기존의 변수에 사칙연산을 가하여 정확도를 높이는 변수를 추가하는 기법
# 티켓 등급별 평균 요금 파생 변수의 추가
Fare_median = df[['Pclass','Fare']].groupby('Pclass').median()
Fare_median
# Out:
#            Fare
# Pclass
# 1       60.0000
# 2       15.0458
# 3        8.0500

# %%
#티켓 등급별 평균 요금
Fare_median = df[['Pclass','Fare']].groupby('Pclass').median().reset_index()
Fare_median
# Out:
#    Pclass     Fare
# 0       1  60.0000
# 1       2  15.0458
# 2       3   8.0500

# %%
Fare_median.columns = ['Pclass','Fare_median']
Fare_median
# Out:
#    Pclass  Fare_median
# 0       1      60.0000
# 1       2      15.0458
# 2       3       8.0500

# %%
# 파생 변수의 병합
# Pclass 변수를 기준으로 join, left: df 기준으로 df는 모든 관측치가 병합됨.
df = pd.merge(df, Fare_median, on='Pclass', how='left')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Fare_median
# 0      0  A/5 21171   7.2500   NaN        S         8.05
# 1      0   PC 17599  71.2833   C85        C        60.00

# %%
# Fare가 결측치(NaN,null)값인 경우 평균값으로 대체
cdt = df['Fare'].isnull()
cdt
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: Fare, Length: 1309, dtype: bool

# %%
df[cdt] #Pclass가 3이므로 3등급의 Fare의 중위수가 할당
# Out:
#       PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 1043         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked  Fare_median
# 1043      0   3701   NaN   NaN        S         8.05

# %%
#Fare가 결측치(NaN, null)값인 경우 중위수로 대체
df.loc[cdt, 'Fare'] = df['Fare_median']
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# Fare_median       0
# dtype: int64

# %%
df.loc[1042:1044,:] #index 1043 확인
# Out:
#       PassengerId  Survived  Pclass  \
# 1042         1043       NaN       3
# 1043         1044       NaN       3
# 1044         1045       NaN       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1042                            Matinoff, Mr. Nicola    male   NaN      0
# 1043                              Storey, Mr. Thomas    male  60.5      0
# 1044  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)  female  36.0      0
#
#       Parch  Ticket     Fare Cabin Embarked  Fare_median
# 1042      0  349255   7.8958   NaN        C         8.05
# 1043      0    3701   8.0500   NaN        S         8.05
# 1044      2  350405  12.1833   NaN        S         8.05

# %%
df= df.drop('Fare_median',axis=1)

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.276193
# std       0.865560    51.743584
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200
